# %%
st={}#dictionary
st1=set()#set
print(type(st))
print(type(st1))
# Out:
# <class 'dict'>
# <class 'set'>

# %%
st={1,2,3,1,2,'hello',3.5}
print(st)
# Out:
# {1, 2, 3, 3.5, 'hello'}

# %%
st={1,2,3,1,2,'hello',3.5,(4,5,3,6)}
for i in st:
    print(i,end=" "),
# Out:
# (4, 5, 3, 6) 1 2 3.5 3 hello

# %%
#delete
st.remove(3)
print(st)
st.discard(2)
print(st)
# del st
# Out:
# {(4, 5, 3, 6), 1, 2, 3.5, 'hello'}
# {(4, 5, 3, 6), 1, 3.5, 'hello'}

# %%
st={1,2,3,1,2,3,'hello',3.5,(4,5,7,3,6)}
st.add(20);
st.add((20,30,4))
st.update((50,70,60))
print(st)
# Out:
# {1, 2, 3, 3.5, 70, (4, 5, 7, 3, 6), 20, 'hello', 50, 60, (20, 30, 4)}
