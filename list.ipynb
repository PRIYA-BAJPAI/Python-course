# %%
#List Creation
lst=[1,2,3,4,"hello",[7,8,9],5]
for i in lst:
    print(i);
# Out:
# 1
# 2
# 3
# 4
# hello
# [7, 8, 9]
# 5

# %%
#List Slicing
lst=[3,12,15,17,5,8,9,2,11,15]
x=lst[ :5:-3]
y=lst[3:8:2]
z=lst[ :5:3]
print(x)
print(y)
print(z)
# Out:
# [15, 9]
# [17, 8, 2]
# [3, 17]
